# %% [markdown]
# <a href="https://colab.research.google.com/github/diogobelchor/FIap_aula02/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.random.mtrand import randn

import numpy as np

from matplotlib import pyplot as plt



y = 20 * np.random.randn(80)

x = [x for x in range(len(y))]



plt.plot(x, y, '-')

plt.fill_between(x, y, 100, where=(y > 50), facecolor= 'g', alpha=.6)

plt.title('Exemplo de Gráfico')

plt.show()
